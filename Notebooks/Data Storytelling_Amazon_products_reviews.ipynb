# %% [markdown]
# ## Capstone Project 1: Data Storytelling

# %% [markdown]
# Data Source:  http://jmcauley.ucsd.edu/data/amazon/
#
# For this project I will use three product categories datasets: baby products, grocery and gourment foods, and cellephones dataset.
#
# The objective of my Capstone project 1 (sentiment Analysis of Amazon product reviews) is to determine polarity of a review text i.e. whether a given review is positive (rating: 4 or 5) or negative(rating 1 or 2) based on ratings and reviews, which can help businesses make decision based on customer reviews.
#
# In this exploration of Amazon product reviews dataset, I will analyse the features of review text with respect to ratings.
# These are the questions I will look in the data:
#
# - How the distribution of data based on review categories (or star ratings) and distribution of review length looks like?
# - How the distribution of number of ratings in different product categories looks like?
# - How the reviews change across high and low star ratings based on review length and percentage of UPPERCASE words per review
#   for different product categories?
# - what are the most frequently used words for high and low ratings and it's vizualization with word clouds?

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

import matplotlib.pyplot as plt
import seaborn as sns

import nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from wordcloud import WordCloud

# %% [markdown]
# #### JSON files loaded to pandas DatFrame for the three product categories

# %%
# Read json file into a pandas Dataframe

baby_products = pd.read_json('Baby_5.json', lines=True)

# Take a look at the first 5 rows
baby_products.head(2)
# Out:
#        reviewerID        asin                        reviewerName helpful  \
# 0  A1HK2FQW6KXQB2  097293751X  Amanda Johnsen "Amanda E. Johnsen"  [0, 0]
# 1  A19K65VY14D13R  097293751X                              angela  [0, 0]
#
#                                           reviewText  overall  \
# 0  Perfect for new parents. We were able to keep ...        5
# 1  This book is such a life saver.  It has been s...        5
#
#                                    summary  unixReviewTime   reviewTime
# 0                                  Awesine      1373932800  07 16, 2013
# 1  Should be required for all new parents!      1372464000  06 29, 2013

# %%
grocery_foods = pd.read_json('Grocery_and_Gourmet_Food_5.json', lines=True)
grocery_foods.head(2)
# Out:
#        reviewerID        asin     reviewerName helpful  \
# 0  A1VEELTKS8NLZB  616719923X  Amazon Customer  [0, 0]
# 1  A14R9XMZVJ6INB  616719923X          amf0001  [0, 1]
#
#                                           reviewText  overall  \
# 0  Just another flavor of Kit Kat but the taste i...        4
# 1  I bought this on impulse and it comes from Jap...        3
#
#                                              summary  unixReviewTime  \
# 0                                         Good Taste      1370044800
# 1  3.5 stars,  sadly not as wonderful as I had hoped      1400457600
#
#     reviewTime
# 0   06 1, 2013
# 1  05 19, 2014

# %%
cell_phones = pd.read_json('Cell_Phones_and_Accessories_5.json', lines=True)
cell_phones.head(2)
# Out:
#        reviewerID        asin reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X    christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X     emily l.  [0, 0]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
#
#                  summary  unixReviewTime   reviewTime
# 0             Looks Good      1400630400  05 21, 2014
# 1  Really great product.      1389657600  01 14, 2014

# %%
# column names
baby_products.columns
# Out:
# Index(['reviewerID', 'asin', 'reviewerName', 'helpful', 'reviewText',
#        'overall', 'summary', 'unixReviewTime', 'reviewTime'],
#       dtype='object')

# %%
# Rename the columns 

baby_products = baby_products.rename(columns = {'overall': 'rating', 'summary': 'review_summary'})


grocery_foods = grocery_foods.rename(columns = {'overall': 'rating', 'summary': 'review_summary'})

cell_phones = cell_phones.rename(columns = {'overall': 'rating', 'summary': 'review_summary'})
cell_phones.head(2)
# Out:
#        reviewerID        asin reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X    christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X     emily l.  [0, 0]
#
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary  unixReviewTime   reviewTime
# 0             Looks Good      1400630400  05 21, 2014
# 1  Really great product.      1389657600  01 14, 2014

# %%
# Find out total no of rows and columns

baby_products.shape
# Out:
# (160792, 9)

# %%
grocery_foods.shape
# Out:
# (151254, 9)

# %%
cell_phones.shape
# Out:
# (194439, 9)

# %% [markdown]
# #### Find if there is any missing value in datasets and count them.

# %%
# Any misssing values ?
baby_products.isnull().values.any()
# Out:
# True

# %%
grocery_foods.isnull().values.any()
# Out:
# True

# %%
cell_phones.isnull().values.any()
# Out:
# True

# %%
# Count missing values
baby_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160792 entries, 0 to 160791
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      160792 non-null  object
#  1   asin            160792 non-null  object
#  2   reviewerName    159427 non-null  object
#  3   helpful         160792 non-null  object
#  4   reviewText      160792 non-null  object
#  5   rating          160792 non-null  int64
#  6   review_summary  160792 non-null  object
#  7   unixReviewTime  160792 non-null  int64
#  8   reviewTime      160792 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 11.0+ MB

# %%
grocery_foods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151254 entries, 0 to 151253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      151254 non-null  object
#  1   asin            151254 non-null  object
#  2   reviewerName    149761 non-null  object
#  3   helpful         151254 non-null  object
#  4   reviewText      151254 non-null  object
#  5   rating          151254 non-null  int64
#  6   review_summary  151254 non-null  object
#  7   unixReviewTime  151254 non-null  int64
#  8   reviewTime      151254 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 10.4+ MB

# %%
cell_phones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194439 entries, 0 to 194438
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   reviewerID      194439 non-null  object
#  1   asin            194439 non-null  object
#  2   reviewerName    190920 non-null  object
#  3   helpful         194439 non-null  object
#  4   reviewText      194439 non-null  object
#  5   rating          194439 non-null  int64
#  6   review_summary  194439 non-null  object
#  7   unixReviewTime  194439 non-null  int64
#  8   reviewTime      194439 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 13.4+ MB

# %%
# Total number of missing values
print(baby_products.isnull().sum().sum())
print(grocery_foods.isnull().sum().sum())
print(cell_phones.isnull().sum().sum())
# Out:
# 1365
# 1493
# 3519

# %% [markdown]
# There are missing values only in the reviewer's name attribute. For our analysis I will be using only the reviewText and ratings columns. So I will not remove the missing value rows because it does not change the analysis in either ways.

# %%
# Keep the review columns and rating (drop the rest of the columns)

baby_products = baby_products.drop(columns=['reviewerID', 'asin', 'reviewerName', 'helpful', 'unixReviewTime', 'reviewTime'])
grocery_foods = grocery_foods.drop(columns=['reviewerID', 'asin', 'reviewerName', 'helpful', 'unixReviewTime', 'reviewTime'])
cell_phones = cell_phones.drop(columns=['reviewerID', 'asin', 'reviewerName', 'helpful', 'unixReviewTime', 'reviewTime'])
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary
# 0             Looks Good
# 1  Really great product.

# %% [markdown]
# #### Check for duplicate review text rows and drop them

# %%
# Check for duplicate reviewText 

duplicate_rev_baby = baby_products.duplicated(subset='reviewText', keep='first').sum()
duplicate_rev_baby
# Out:
# 69

# %%
duplicate_rev_food = grocery_foods.duplicated(subset='reviewText', keep='first').sum()
duplicate_rev_food
# Out:
# 55

# %%
duplicate_rev_phone = cell_phones.duplicated(subset='reviewText', keep='first').sum()
duplicate_rev_phone
# Out:
# 253

# %%
# Drop duplicate reviewText
baby_products = baby_products.drop_duplicates(subset = 'reviewText', keep='first')
len(baby_products)
# Out:
# 160723

# %%
grocery_foods = grocery_foods.drop_duplicates(subset = 'reviewText', keep='first')
len(grocery_foods)
# Out:
# 151199

# %%
cell_phones = cell_phones.drop_duplicates(subset = 'reviewText', keep='first')
len(cell_phones)
# Out:
# 194186

# %% [markdown]
# #### I will remove short review text of less than 3 words. Because sentiment analysis are less effective when review texts are short

# %%
# Remove short reviewText: less than < 3 words

def remove_short_review(text):
    length = len(text.split())
    if length >= 3:
        return True
    else:
        return False
    
baby_products = baby_products[baby_products['reviewText'].apply(lambda x:remove_short_review(x))]
len(baby_products)
# Out:
# 160662

# %%
grocery_foods = grocery_foods[grocery_foods['reviewText'].apply(lambda x: remove_short_review(x))]
len(grocery_foods)
# Out:
# 151054

# %%
cell_phones = cell_phones[cell_phones['reviewText'].apply(lambda x: remove_short_review(x))]
len(cell_phones)
# Out:
# 193876

# %%
pd.to_pickle(baby_products, 'baby_products_stats.pkl')

# %%
pd.to_pickle(grocery_foods, 'grocery_foods_stats.pkl')

# %%
pd.to_pickle(cell_phones, 'cell_phones_stats.pkl')

# %% [markdown]
# #### Remove non_English reviews

# %%
from langdetect import detect

def mydetect(txt):
    try:
        return detect(txt)
    except LangDetectException:
        pass

baby_products['clean_review_baby'] = baby_products['reviewText'].apply(lambda x: mydetect(x))
baby_products.head(2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-f1868227d157> in <module>
# ----> 1 from langdetect import detect
#       2
#       3 def mydetect(txt):
#       4     try:
#       5         return detect(txt)
#
# ModuleNotFoundError: No module named 'langdetect'

# %%
#for e in baby_products['reviewText']:
    #try:
        #if detect(e) == 'en':
            #print(e)
    #except LangDetectException:
        #pass

# %%
# Remove non-English using NLTK
import nltk 
nltk.download('words')
words = set(nltk.corpus.words.words())

def remove_non_en(text):
    text = " ".join(w.lower() for w in nltk.wordpunct_tokenize(text) if w.lower() in words or not w.isalpha())
    return text
baby_products['clean_review_baby'] = baby_products['reviewText'].apply(lambda x: remove_non_en(x))
baby_products.head(2)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/pravatiswain/nltk_data...
# [nltk_data]   Package words is already up-to-date!
#                                           reviewText  rating  \
# 0  Perfect for new parents. We were able to keep ...       5
# 1  This book is such a life saver.  It has been s...       5
#
#                             review_summary  \
# 0                                  Awesine
# 1  Should be required for all new parents!
#
#                                    clean_review_baby
# 0  perfect for new . we were able to keep track o...
# 1  this book is such a life saver . it been so he...

# %%
grocery_foods['clean_review_food'] = grocery_foods['reviewText'].apply(lambda x: remove_non_en(x))
grocery_foods.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Just another flavor of Kit Kat but the taste i...       4
# 1  I bought this on impulse and it comes from Jap...       3
#
#                                       review_summary  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
#
#                                    clean_review_food
# 0  just another flavor of kit kat but the taste i...
# 1  i bought this on impulse and it comes from jap...

# %%
cell_phones['clean_review_phone']= cell_phones['reviewText'].apply(lambda x: remove_non_en(x))
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary                                 clean_review_phone
# 0             Looks Good  they look good and stick good ! i just don ' t...
# 1  Really great product.  these stickers work like the review they do . ...

# %%
rev_per_rating_baby = baby_products['rating'].value_counts().sort_index()
rev_per_rating_baby
# Out:
# 1     7808
# 2     9188
# 3    17249
# 4    32977
# 5    93440
# Name: rating, dtype: int64

# %%
plt.pie(rev_per_rating_baby, labels=[1, 2, 3, 4, 5], startangle=90, autopct='%.0f%%');

# %%
# % of reviews per rating baby products
rev_percent_baby = (rev_per_rating_baby/rev_per_rating_baby.sum())*100
rev_percent_baby
# Out:
# 1     4.859892
# 2     5.718838
# 3    10.736204
# 4    20.525700
# 5    58.159366
# Name: rating, dtype: float64

# %%
baby_products['rating'].value_counts().sort_index().sum()
# Out:
# 160662

# %%
rev_per_rating_food = grocery_foods['rating'].value_counts().sort_index()
rev_per_rating_food
# Out:
# 1     5772
# 2     7914
# 3    17505
# 4    32565
# 5    87298
# Name: rating, dtype: int64

# %%
# % of reviews per rating grocery_foods
rev_percent_food = (rev_per_rating_food/rev_per_rating_food.sum())*100
rev_percent_food
# Out:
# 1     3.821150
# 2     5.239186
# 3    11.588571
# 4    21.558515
# 5    57.792577
# Name: rating, dtype: float64

# %%
rev_per_rating_phone = cell_phones['rating'].value_counts().sort_index()
rev_per_rating_phone
# Out:
# 1     13247
# 2     11052
# 3     21400
# 4     39896
# 5    108281
# Name: rating, dtype: int64

# %%
# % of reviews per rating cell phones
rev_percent_phone = (rev_per_rating_phone/rev_per_rating_phone.sum())*100
rev_percent_phone
# Out:
# 1     6.832718
# 2     5.700551
# 3    11.037983
# 4    20.578101
# 5    55.850647
# Name: rating, dtype: float64

# %% [markdown]
# ### Distributions

# %%
# Rating Distributions
plt.figure(figsize=(18, 6))
plt.subplot(1,3,1); baby_products['rating'].value_counts().sort_index().plot(kind='bar', rot = 0,color='#348ABD', title='Baby Products', alpha=0.8).set(xlabel='Rating', ylabel="Number of Reviews")
plt.subplot(1,3,2); grocery_foods['rating'].value_counts().sort_index().plot(kind='bar', rot= 0,color='#A60628', title='Grocery_Foods', alpha=0.8).set(xlabel='Rating', ylabel="Number of Reviews")
plt.subplot(1,3,3);cell_phones['rating'].value_counts().sort_index().plot(kind='bar', rot =0, color='#467821', title='Cell Phones', alpha=0.8).set(xlabel='Rating', ylabel="Number of Reviews")
plt.tight_layout(pad=2)

# %% [markdown]
# We notice that most of the reviews are five stars in all the three product categories

# %%
# Review length Distribution
rev_categories = pd.concat([baby_products['reviewText'].apply(lambda x: len(x.split())), grocery_foods['reviewText'].apply(lambda x: len(x.split())), cell_phones['reviewText'].apply(lambda x: len(x.split()))], axis=1, keys=['rev_baby', 'rev_food', 'rev_phone'])
rev_categories.head(2)
# Out:
#    rev_baby  rev_food  rev_phone
# 0      47.0      31.0       37.0
# 1     105.0     114.0       32.0

# %%
color= {'rev_baby':'#348ABD', 'rev_food': '#A60628', 'rev_phone': '#467821'}
sns.boxplot(x='variable', y='value', data=pd.melt(rev_categories),showfliers=False,  palette=color).set(ylabel='Review Length', xlabel='Category')
plt.show()

# %%
len_100_less_baby = np.mean([1 if i <= 100 else 0 for i in rev_categories['rev_baby']]) * 100
print('Percentage of review length less than equal to 100 in baby product category = ', len_100_less_baby)
# Out:
# Percentage of review length less than equal to 100 in baby product category =  56.25283119878104

# %%
len_100_less_food = np.mean([1 if i <= 100 else 0 for i in rev_categories['rev_food']]) * 100
print('Percentage of review length less than equal to 100 in grocery foods product category = ', len_100_less_food)
# Out:
# Percentage of review length less than equal to 100 in grocery foods product category =  53.16630976403245

# %%
len_100_less_phone = np.mean([1 if i <= 100 else 0 for i in rev_categories['rev_phone']]) * 100
print('Percentage of review length less than equal to 100 in cell phones product category = ', len_100_less_phone)
# Out:
# Percentage of review length less than equal to 100 in cell phones product category =  74.80541942923033

# %% [markdown]
# From the review length distribution, we can see the cell phone reviews are of shorter length compared to the other two product categories. There are 74.8% of cell phone reviews of length less than equal to 100. Whereas, baby products and grocery food categories have about 56% and 53% of reviews of length less than or equal to 100 respectively.

# %% [markdown]
# #### Distribution of review length and percentage of UPPERCASE per review across the different levels of star ratings

# %%
# baby_products distribution

rev_rating = baby_products[['rating', 'reviewText']]

rev_rating_copy = rev_rating.copy()
rev_rating_copy['rev_length'] = rev_rating_copy['reviewText'].apply(lambda x: len(x.split())) # review length

def caps(text):
    return np.mean([1 if i.isupper() else 0 for i in text]) * 100

rev_rating_copy['capitals']= rev_rating_copy['reviewText'].apply(caps) # % caps

rating_len_cap_baby = rev_rating_copy[['rating', 'rev_length', 'capitals']]
rating_len_cap_baby.head(2)
# Out:
#    rating  rev_length  capitals
# 0       5          47  1.185771
# 1       5         105  0.899281

# %%
# Grocery_foods_Distribution

rev_rating = grocery_foods[['rating', 'reviewText']]

rev_rating_copy = rev_rating.copy()
rev_rating_copy['rev_length'] = rev_rating_copy['reviewText'].apply(lambda x: len(x.split())) # review length



rev_rating_copy['capitals']= rev_rating_copy['reviewText'].apply(caps) # % caps

rating_len_cap_food = rev_rating_copy[['rating', 'rev_length', 'capitals']]
rating_len_cap_food.head(2)
# Out:
#    rating  rev_length  capitals
# 0       4          31  3.086420
# 1       3         114  1.543739

# %%
# Cell_phones_Distribution
rev_rating = cell_phones[['rating', 'reviewText']]

rev_rating_copy = rev_rating.copy()
rev_rating_copy['rev_length'] = rev_rating_copy['reviewText'].apply(lambda x: len(x.split())) # review length


rev_rating_copy['capitals']= rev_rating_copy['reviewText'].apply(caps) # % caps

rating_len_cap_phone = rev_rating_copy[['rating', 'rev_length', 'capitals']]
rating_len_cap_phone.head(2)
# Out:
#    rating  rev_length  capitals
# 0       4          37  2.645503
# 1       5          32  2.500000

# %%
# rating and review length distribution
plt.figure(figsize=(18, 6))
plt.subplot(1,3,1); sns.boxplot(x = 'rating', y = 'rev_length', data = rating_len_cap_baby, showfliers=False, color='#348ABD').set(xlabel= 'Rating', ylabel='Review Length', title='Baby Products')
plt.subplot(1,3,2); sns.boxplot(x = 'rating', y = 'rev_length', data = rating_len_cap_food, showfliers=False, color='#A60628').set(xlabel= 'Rating', ylabel='Review Length', title='Grocery_Foods')
plt.subplot(1,3,3);sns.boxplot(x = 'rating', y = 'rev_length', data = rating_len_cap_phone, showfliers=False, color='#467821').set(xlabel= 'Rating', ylabel='Review Length', title='Cell Phones')
plt.tight_layout(pad=2)

# %% [markdown]
# In all of the three product categories, reviews corresponding to five star ratings are shorter length.

# %%
# Rating and % caps distribution 
plt.figure(figsize=(18,6))
plt.subplot(1,3,1);sns.boxplot(x = 'rating', y = 'capitals', data = rating_len_cap_baby, showfliers=False, color='#348ABD').set(xlabel= 'Rating',ylabel='% of Capitals', title='Baby Products')

plt.subplot(1,3,2);sns.boxplot(x = 'rating', y = 'capitals', data = rating_len_cap_food, showfliers=False,color='#A60628').set(xlabel= 'Rating',ylabel='% of Capitals',title='Grocery_Foods')

plt.subplot(1,3,3);sns.boxplot(x = 'rating', y = 'capitals', data = rating_len_cap_phone, showfliers=False, color='#467821').set(xlabel= 'Rating',ylabel='% of Capitals',title='Cell Phones')
plt.tight_layout(pad=2)

# %% [markdown]
# In all the three product categories, reviews corresponding to 1 star and 5 star ratings have more uppercase letters

# %%
# Distribution of % caps baby_products

plt.figure(figsize=(18, 6))
plt.subplot(1,3,1)

rating_len_cap_baby['capitals'].hist(color='#348ABD', alpha=0.8)
plt.yscale('log', nonposy='clip')
plt.title('Baby Products')
plt.xlabel('% of Capitals')
plt.ylabel('Count')

# Distribution of % caps grocery_food
plt.subplot(1,3,2); rating_len_cap_food['capitals'].hist(color='#A60628', alpha=0.8)
plt.yscale('log', nonposy='clip')
plt.title('Grocery_Foods')
plt.xlabel('%caps')
plt.ylabel('Count')

# Distribution of % caps cell_phones
plt.subplot(1,3,3); rating_len_cap_phone['capitals'].hist(color='#467821', alpha=0.8)
plt.yscale('log', nonposy='clip')
plt.title('Cell Phones')
plt.xlabel('% of Capitals')
plt.ylabel('Count')

plt.tight_layout(pad=2.0)

# %%
# Distribution of % caps(>60%) vs ratings
rating_len_cap_baby['many_caps'] = rating_len_cap_baby['capitals'].apply(lambda x: x > 60)
rating_len_cap_food['many_caps'] = rating_len_cap_food['capitals'].apply(lambda x: x > 60)
rating_len_cap_phone['many_caps'] = rating_len_cap_phone['capitals'].apply(lambda x: x > 60)

baby_caps = rating_len_cap_baby[['rating','many_caps']].groupby('rating').mean()
food_caps = rating_len_cap_food[['rating','many_caps']].groupby('rating').mean()
phone_caps = rating_len_cap_phone[['rating','many_caps']].groupby('rating').mean()


fig, axes = plt.subplots(1, 3, figsize= (18,6))

baby_caps.plot(kind='bar', ax=axes[0], color='#348ABD',rot = 0, alpha=0.8).set(xlabel='Rating', ylabel='% Reviews with >60% Capitals')
food_caps.plot(kind='bar', ax=axes[1], color='#A60628',rot = 0, alpha=0.8).set(xlabel='Rating', ylabel='% Reviews with >60% Capitals')
phone_caps.plot(kind='bar', ax=axes[2], color='#467821',rot = 0, alpha=0.8).set(xlabel='Rating',ylabel='% Reviews with >60% Capitals')

axes[0].set_title('Baby Products')
axes[1].set_title('Grocery_Foods')
axes[2].set_title('Cell Phones')
plt.tight_layout(pad=2.0)

# %% [markdown]
# For all the three product categories the % caps shows bimodal distribution. The reviews containing greater than 60% uppercase letters are mostly rated 1 star and 5 stars.

# %% [markdown]
# ### Text Pre-Processing
#
#
# - Remove punctuations
# - Remove Stopwords
# - Tokenization: converting a sentence into a list of words
# - Lower case
# - Stemming/ Lemmatization: Reduce a word to it's root or base units

# %%
# Remove punctuations

baby_products['clean_review_baby'] = baby_products['clean_review_baby'].str.replace('[^\w\s]','')
baby_products.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Perfect for new parents. We were able to keep ...       5
# 1  This book is such a life saver.  It has been s...       5
#
#                             review_summary  \
# 0                                  Awesine
# 1  Should be required for all new parents!
#
#                                    clean_review_baby
# 0  perfect for new  we were able to keep track of...
# 1  this book is such a life saver  it been so hel...

# %%
grocery_foods['clean_review_food'] = grocery_foods['clean_review_food'].str.replace('[^\w\s]','')
grocery_foods.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Just another flavor of Kit Kat but the taste i...       4
# 1  I bought this on impulse and it comes from Jap...       3
#
#                                       review_summary  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
#
#                                    clean_review_food
# 0  just another flavor of kit kat but the taste i...
# 1  i bought this on impulse and it comes from jap...

# %%
cell_phones['clean_review_phone'] = cell_phones['clean_review_phone'].str.replace('[^\w\s]','')
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary                                 clean_review_phone
# 0             Looks Good  they look good and stick good  i just don  t l...
# 1  Really great product.  these stickers work like the review they do  t...

# %%
# Remove Stop Words
import nltk
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')


baby_products['clean_review_baby'] = baby_products['clean_review_baby'].apply(lambda x: " ".join(w for w in x.split() if w not in stop_words))
baby_products.head(2)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pravatiswain/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                           reviewText  rating  \
# 0  Perfect for new parents. We were able to keep ...       5
# 1  This book is such a life saver.  It has been s...       5
#
#                             review_summary  \
# 0                                  Awesine
# 1  Should be required for all new parents!
#
#                                    clean_review_baby
# 0  perfect new able keep track baby feeding sleep...
# 1  book life saver helpful able go back track ans...

# %%
len(baby_products)
# Out:
# 160662

# %%
grocery_foods['clean_review_food'] = grocery_foods['clean_review_food'].apply(lambda x: " ".join(w for w in x.split() if w not in stop_words))
grocery_foods.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Just another flavor of Kit Kat but the taste i...       4
# 1  I bought this on impulse and it comes from Jap...       3
#
#                                       review_summary  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
#
#                                    clean_review_food
# 0  another flavor kit kat taste unique bit differ...
# 1  bought impulse comes japan amused family weird...

# %%
cell_phones['clean_review_phone'] = cell_phones['clean_review_phone'].apply(lambda x: " ".join(w for w in x.split() if w not in stop_words))
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary                                 clean_review_phone
# 0             Looks Good  look good stick good like rounded shape always...
# 1  Really great product.  stickers work like review stick great stay pho...

# %% [markdown]
# #### Tokenization

# %%
# import libraries
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize


# tokenize 

def tokenization(text):
    return word_tokenize(text)

baby_products['clean_rev_token_baby'] = baby_products['clean_review_baby'].apply(lambda x: tokenization(x.lower()))
baby_products.head(2)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/pravatiswain/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                           reviewText  rating  \
# 0  Perfect for new parents. We were able to keep ...       5
# 1  This book is such a life saver.  It has been s...       5
#
#                             review_summary  \
# 0                                  Awesine
# 1  Should be required for all new parents!
#
#                                    clean_review_baby  \
# 0  perfect new able keep track baby feeding sleep...
# 1  book life saver helpful able go back track ans...
#
#                                 clean_rev_token_baby
# 0  [perfect, new, able, keep, track, baby, feedin...
# 1  [book, life, saver, helpful, able, go, back, t...

# %%
grocery_foods['clean_rev_token_food'] = grocery_foods['clean_review_food'].apply(lambda x: tokenization(x.lower()))
grocery_foods.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Just another flavor of Kit Kat but the taste i...       4
# 1  I bought this on impulse and it comes from Jap...       3
#
#                                       review_summary  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
#
#                                    clean_review_food  \
# 0  another flavor kit kat taste unique bit differ...
# 1  bought impulse comes japan amused family weird...
#
#                                 clean_rev_token_food
# 0  [another, flavor, kit, kat, taste, unique, bit...
# 1  [bought, impulse, comes, japan, amused, family...

# %%
cell_phones['clean_rev_token_phone'] = cell_phones['clean_review_phone'].apply(lambda x: tokenization(x.lower()))
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary                                 clean_review_phone  \
# 0             Looks Good  look good stick good like rounded shape always...
# 1  Really great product.  stickers work like review stick great stay pho...
#
#                                clean_rev_token_phone
# 0  [look, good, stick, good, like, rounded, shape...
# 1  [stickers, work, like, review, stick, great, s...

# %%
pd.to_pickle(grocery_foods, 'grocery_foods.pkl')

# %%
pd.to_pickle(cell_phones, 'cell_phones.pkl')

# %%
pd.to_pickle(baby_products, 'baby_products.pkl')

# %%
# Stemming
nltk.download('wordnet')
from nltk.stem import PorterStemmer 
ps = PorterStemmer()

def stemming(text):
    text = ' '.join(ps.stem(word) for word in text)
    return text

baby_products['clean_rev_stem_baby'] = baby_products['clean_rev_token_baby'].apply(lambda x: stemming(x))
baby_products.head(2)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/pravatiswain/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
#                                           reviewText  rating  \
# 0  Perfect for new parents. We were able to keep ...       5
# 1  This book is such a life saver.  It has been s...       5
#
#                             review_summary  \
# 0                                  Awesine
# 1  Should be required for all new parents!
#
#                                    clean_review_baby  \
# 0  perfect new able keep track baby feeding sleep...
# 1  book life saver helpful able go back track ans...
#
#                                 clean_rev_token_baby  \
# 0  [perfect, new, able, keep, track, baby, feedin...
# 1  [book, life, saver, helpful, able, go, back, t...
#
#                                  clean_rev_stem_baby
# 0  perfect new abl keep track babi feed sleep dia...
# 1  book life saver help abl go back track answer ...

# %%
grocery_foods['clean_rev_stem_food'] = grocery_foods['clean_rev_token_food'].apply(lambda x: stemming(x))
grocery_foods.head(2)
# Out:
#                                           reviewText  rating  \
# 0  Just another flavor of Kit Kat but the taste i...       4
# 1  I bought this on impulse and it comes from Jap...       3
#
#                                       review_summary  \
# 0                                         Good Taste
# 1  3.5 stars,  sadly not as wonderful as I had hoped
#
#                                    clean_review_food  \
# 0  another flavor kit kat taste unique bit differ...
# 1  bought impulse comes japan amused family weird...
#
#                                 clean_rev_token_food  \
# 0  [another, flavor, kit, kat, taste, unique, bit...
# 1  [bought, impulse, comes, japan, amused, family...
#
#                                  clean_rev_stem_food
# 0  anoth flavor kit kat tast uniqu bit differ thi...
# 1  bought impuls come japan amus famili weird pac...

# %%
cell_phones['clean_rev_stem_phone'] = cell_phones['clean_rev_token_phone'].apply(lambda x: stemming(x))
cell_phones.head(2)
# Out:
#                                           reviewText  rating  \
# 0  They look good and stick good! I just don't li...       4
# 1  These stickers work like the review says they ...       5
#
#           review_summary                                 clean_review_phone  \
# 0             Looks Good  look good stick good like rounded shape always...
# 1  Really great product.  stickers work like review stick great stay pho...
#
#                                clean_rev_token_phone  \
# 0  [look, good, stick, good, like, rounded, shape...
# 1  [stickers, work, like, review, stick, great, s...
#
#                                 clean_rev_stem_phone
# 0  look good stick good like round shape alway bu...
# 1  sticker work like review stick great stay phon...

# %% [markdown]
# ### Word Clouds for high ratings vs low ratings

# %% [markdown]
# ##### Baby_Products Word Clouds

# %%
high_rating_baby = baby_products.drop(columns=['reviewText','review_summary','clean_rev_token_baby', 'clean_rev_stem_baby'])[baby_products.rating >=4]
high_rating_baby.head(2)
# Out:
#    rating                                  clean_review_baby
# 0       5  perfect new able keep track baby feeding sleep...
# 1       5  book life saver helpful able go back track ans...

# %%
low_rating_baby = baby_products.drop(columns=['reviewText','review_summary','clean_rev_token_baby', 'clean_rev_stem_baby'])[baby_products.rating <3]
low_rating_baby.head(2)
# Out:
#     rating                                  clean_review_baby
# 74       1  ridiculous huge hard clamp daughter idea going...
# 92       1  product little boy chew teething hard never ab...

# %%
high_baby = " ".join(review for review in high_rating_baby.clean_review_baby)
low_baby = " ".join(review for review in low_rating_baby.clean_review_baby)

# %%
# import library

from wordcloud import WordCloud, STOPWORDS , ImageColorGenerator 
import matplotlib.pyplot as plt
import os
from os import path, getcwd
from PIL import Image




fig, axs = plt.subplots(1, 2, figsize  = (18,6))

# Read the mask image

apple_mask = np.array(Image.open("apple.png"))

# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=50, max_words=100,mask=apple_mask, background_color="white").generate(high_baby)
wordcloud_low = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(low_baby)

# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (Baby)', fontsize=20)
axs[0].axis('off')

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (Baby)', fontsize=20)
axs[1].axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ##### Grocery_Food Word Clouds

# %%
high_rating_food = grocery_foods.drop(columns=['reviewText','review_summary','clean_rev_token_food', 'clean_rev_stem_food'])[grocery_foods.rating >=4]
high_rating_food.head(2)
# Out:
#    rating                                  clean_review_food
# 0       4  another flavor kit kat taste unique bit differ...
# 2       4  really good great gift fan green tea expensive...

# %%
low_rating_food = grocery_foods.drop(columns=['reviewText','review_summary','clean_rev_token_food', 'clean_rev_stem_food'])[grocery_foods.rating <3]
low_rating_food.head(2)
# Out:
#     rating                                  clean_review_food
# 9        1  love green tea love kit two belong together ha...
# 32       1  product near natural organic wish seen want lo...

# %%
high_food = " ".join(review for review in high_rating_food.clean_review_food)
low_food = " ".join(review for review in low_rating_food.clean_review_food)

# %%
# import library

from wordcloud import WordCloud, STOPWORDS , ImageColorGenerator 
import matplotlib.pyplot as plt




fig, axs = plt.subplots(1, 2, figsize  = (18,6))


# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(high_food)
wordcloud_low = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(low_food)

# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (Food)', fontsize=20)
axs[0].axis('off')

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (Food)', fontsize=20)
axs[1].axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ##### Cell_Phones Word Clouds

# %%
high_rating_phone = cell_phones.drop(columns=['reviewText','review_summary','clean_rev_token_phone', 'clean_rev_stem_phone'])[cell_phones.rating >=4]
high_rating_phone.head(2)
# Out:
#    rating                                 clean_review_phone
# 0       4  look good stick good like rounded shape always...
# 1       5  stickers work like review stick great stay pho...

# %%
low_rating_phone = cell_phones.drop(columns=['reviewText','review_summary','clean_rev_token_phone', 'clean_rev_stem_phone'])[cell_phones.rating <3]
low_rating_phone.head(2)
# Out:
#     rating                                 clean_review_phone
# 7        1      worked first week charge phone 20 waste money
# 19       1  worked great first couple stopped completely b...

# %%
high_phone = " ".join(review for review in high_rating_phone.clean_review_phone)
low_phone = " ".join(review for review in low_rating_phone.clean_review_phone)

# %%
# import library

from wordcloud import WordCloud, STOPWORDS , ImageColorGenerator 
import matplotlib.pyplot as plt




fig, axs = plt.subplots(1, 2, figsize  = (18,6))


# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(high_phone)
wordcloud_low = WordCloud(max_font_size=50, max_words=50, background_color="white").generate(low_phone)

# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (phone)', fontsize=20)
axs[0].axis('off')

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (phone)', fontsize=20)
axs[1].axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ##### Word Clouds for Review summary

# %%
summary_high_rating_baby = baby_products.drop(columns=['reviewText', 'clean_review_baby', 'clean_rev_token_baby', 'clean_rev_stem_baby'])[baby_products.rating >4]
summary_high_rating_baby.head(2)
# Out:
#    rating                           review_summary
# 0       5                                  Awesine
# 1       5  Should be required for all new parents!

# %%
summary_low_rating_baby = baby_products.drop(columns=['reviewText', 'clean_review_baby', 'clean_rev_token_baby', 'clean_rev_stem_baby'])[baby_products.rating <3]
summary_low_rating_baby.head(2)
# Out:
#     rating     review_summary
# 74       1  Ridiculous design
# 92       1   Save your money!

# %%
summary_high_baby = ' '.join(rev for rev in summary_high_rating_baby.review_summary)
summary_low_baby = ' '.join(rev for rev in summary_low_rating_baby.review_summary)

# %%
# import library
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, ImageColorGenerator

# Read the mask image

baby_bottle_mask = np.array(Image.open("baby_bottle.jpg"))



fig, axs = plt.subplots(1, 2, figsize  = (18,8))


# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=70, max_words=50,mask=baby_bottle_mask, background_color="white", colormap='winter').generate(summary_high_baby)
wordcloud_low = WordCloud(max_font_size=70, max_words=50,mask=baby_bottle_mask, background_color="white", colormap = 'winter').generate(summary_low_baby)

# create coloring from image
#image_colors = ImageColorGenerator(apple_mask)
# axs[0].imshow(wordcloud_high.recolor(color_func=image_colors), interpolation='bilinear')

# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (Baby Products)', fontsize=20)
axs[0].axis('off')

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (Baby Products)', fontsize=20)
axs[1].axis('off')
# Out:
# (-0.5, 150.5, 384.5, -0.5)

# %%
summary_high_rating_food = grocery_foods.drop(columns=['reviewText', 'clean_review_food', 'clean_rev_token_food', 'clean_rev_stem_food'])[grocery_foods.rating >4]

summary_low_rating_food = grocery_foods.drop(columns=['reviewText', 'clean_review_food', 'clean_rev_token_food', 'clean_rev_stem_food'])[grocery_foods.rating <3]


summary_high_food = ' '.join(rev for rev in summary_high_rating_food.review_summary)
summary_low_food = ' '.join(rev for rev in summary_low_rating_food.review_summary)

# %%
fig, axs = plt.subplots(1, 2, figsize  = (18,8))

# Read the mask image

apple_mask = np.array(Image.open("apple.jpg"))



# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=70, max_words=50,mask=apple_mask, background_color="white", colormap='winter').generate(summary_high_food)
wordcloud_low = WordCloud(max_font_size=70, max_words=50,mask=apple_mask, background_color="white", colormap='winter').generate(summary_low_food)


# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (Grocery_food)', fontsize=20)
axs[0].axis('off');

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (Grocery_food)', fontsize=20)
axs[1].axis('off');

# %%
summary_high_rating_phone = cell_phones.drop(columns=['reviewText', 'clean_review_phone', 'clean_rev_token_phone', 'clean_rev_stem_phone'])[cell_phones.rating > 4]

summary_low_rating_phone = cell_phones.drop(columns=['reviewText', 'clean_review_phone', 'clean_rev_token_phone', 'clean_rev_stem_phone'])[cell_phones.rating <3]


summary_high_phone = ' '.join(rev for rev in summary_high_rating_phone.review_summary)
summary_low_phone = ' '.join(rev for rev in summary_low_rating_phone.review_summary)

# %%
fig, axs = plt.subplots(1, 2, figsize  = (18,8))

# Read the mask image

phone_mask = np.array(Image.open("phone.jpg"))

# Generate WordCloud images

wordcloud_high = WordCloud(max_font_size=70, max_words=50,mask=phone_mask, background_color="white", colormap='winter').generate(summary_high_phone)
wordcloud_low = WordCloud(max_font_size=70, max_words=50,mask=phone_mask, background_color="white", colormap='winter').generate(summary_low_phone)

# Display the image

axs[0].imshow(wordcloud_high, interpolation='bilinear')
axs[0].set_title('High Rating (Phone)', fontsize=20)
axs[0].axis('off')

axs[1].imshow(wordcloud_low, interpolation='bilinear')
axs[1].set_title('Low Rating (Phone)', fontsize=20)
axs[1].axis('off')
# Out:
# (-0.5, 242.5, 406.5, -0.5)
